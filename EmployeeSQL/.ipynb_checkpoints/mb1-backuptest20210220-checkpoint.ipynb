# %% [markdown]
# #### Maria Barrera  -- 02/21/2021
#
# #### Employee SQL DB -- Import into Pandas

# %%
# Pandas
import pandas as pd

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# import psycopg2 for DB connection
import psycopg2

# %% [markdown]
# #do not use
# #Reference:  my postgres connection -- http://127.0.0.1:50506/browser/
# #Create Engine
#
# #HMWK SAMPLE:
# from sqlalchemy import create_engine
# engine = create_engine('postgresql://localhost:5432/<your_db_name>')
# connection = engine.connect()
#
# engine = create_engine('postgresql://postgres:postgres@localhost:5432/employees_db')
# conn = engine.connect()

# %% [markdown]
# #### set-up DB connection -- opt 1
# --
# engine = create_engine('postgresql://postgres:postgres@localhost:5432/employees_db')
# conn = engine.connect()
# conn

# %%
# set-up DB connection -- opt 2
conn = psycopg2.connect(database ="employees_db",  
                            user = "postgres",  
                            password = "postgres",  
                            host = "localhost",  
                            port = "5432") 
conn
# Out:
# <connection object at 0x000001E82D350BF0; dsn: 'user=postgres password=xxx dbname=employees_db host=localhost port=5432', closed: 0>

# %%
# Query All Records in the Database
employees_df = pd.read_sql("SELECT * FROM employees", conn)

# %%
# Preview the Data
employees_df.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
salaries_df = pd.read_sql("SELECT * FROM salaries", conn)
salaries_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
titles_df = pd.read_sql("SELECT * FROM titles", conn)
titles_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
departments_df = pd.read_sql("SELECT * FROM departments", conn)
departments_df.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
dept_emp_df = pd.read_sql("SELECT * FROM dept_emp", conn)
dept_emp_df.head()
# Out:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003

# %%
dept_manager_df = pd.read_sql("SELECT * FROM dept_manager", conn)
dept_manager_df.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %% [markdown]
# #sample
# #create a histogram
#
# #ref:  https://www.geeksforgeeks.org/pandas-dataframe-hist-function-in-python/
# #Importing pandas library
# import pandas as pd
#
# #Creating a Data frame
# values = pd.DataFrame({
#     'Length': [2.7, 8.7, 3.4, 2.4, 1.9],
#     'Breadth': [4.24, 2.67, 7.6, 7.1, 4.9],
#     'Height': [5.8, 5.5, 7.8, 10.88, 0.1]})
#
# #Creating Histograms of columns 'Length',
# #'Breadth' and 'Height' using Dataframe.hist()
# #function
# #hist = values.hist(bins=12)

# %% [markdown]
# SELECT salary, COUNT(*)
# FROM salaries
# GROUP BY
# 	salary
# ORDER BY
# 	COUNT DESC, salary DESC
# ;

# %%
salaries_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
# Create a histogram to visualize the most common salary ranges for employees.
import matplotlib.pyplot as plt
import numpy as np

salaries_df.hist(column='salary')

# Set a Title and labels
plt.title("Salaries by Group")
plt.xlabel("Salary Groups")
plt.ylabel("Salary Range")

plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# count the most common salary ranges for employees
salaries_count_df = salaries_df['salary'].value_counts()
salaries_count_df
# Out:
# 40000    95346
# 55581       19
# 53738       18
# 53078       18
# 47454       17
#          ...
# 74239        1
# 78148        1
# 76103        1
# 79114        1
# 81762        1
# Name: salary, Length: 50355, dtype: int64

# %%
type(salaries_count_df)
# Out:
# pandas.core.series.Series

# %%
# joining the DataFrames 
new_df1 = pd.merge(employees_df, salaries_df, on = "emp_no", how = "inner") 
new_df1
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date  salary
# 0       1990-04-28   40000
# 1       1991-09-07   53422
# 2       1992-03-21   48973
# 3       1987-11-26   40000
# 4       1991-01-18   40000
# ...            ...     ...
# 300019  1988-10-28   69696
# 300020  1995-02-26   75355
# 300021  1988-02-24   61886
# 300022  1994-09-08   62772
# 300023  1987-11-23   41708
#
# [300024 rows x 8 columns]

# %%
# check for duplicates
duplicate = new_df1[new_df1.duplicated()] 
print("Duplicate Rows :") 
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [emp_no, emp_title_id, birth_date, first_name, last_name, sex, hire_date, salary]
# Index: []

# %%
# check # of rows & columns
new_df1.shape
# Out:
# (300024, 8)

# %%
# check for unique
new_df.emp_no.nunique()
# Out:
# 300024

# %%
# check # of rows & columns
titles_df.shape
# Out:
# (7, 2)

# %%
new_df2 = pd.merge(new_df1, titles_df, left_on = 'emp_title_id', right_on = 'title_id')
new_df2
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001  1953-07-25    Hideyuki    Zallocco   M
# 1       421786        s0001  1957-09-28       Xiong    Verhoeff   M
# 2       273487        s0001  1957-04-14   Christoph     Parfitt   M
# 3       246449        s0001  1958-03-23       Subbu  Bultermann   F
# 4        48085        s0001  1964-01-19  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 300019  111400        m0001  1959-11-09        Arie     Staelin   M
# 300020  111133        m0001  1955-03-16       Hauke       Zhang   M
# 300021  110085        m0001  1959-10-28        Ebru       Alpin   M
# 300022  110386        m0001  1953-10-04        Shem      Kieras   M
# 300023  111784        m0001  1956-06-14       Marjo  Giarratana   F
#
#          hire_date  salary title_id    title
# 0       1990-04-28   40000    s0001    Staff
# 1       1987-11-26   40000    s0001    Staff
# 2       1991-06-28   56087    s0001    Staff
# 3       1988-03-25   87084    s0001    Staff
# 4       1993-06-28   63016    s0001    Staff
# ...            ...     ...      ...      ...
# 300019  1985-01-01   72446    m0001  Manager
# 300020  1986-12-30   71148    m0001  Manager
# 300021  1985-01-01   60026    m0001  Manager
# 300022  1988-10-14   40000    m0001  Manager
# 300023  1988-02-12   40000    m0001  Manager
#
# [300024 rows x 10 columns]

# %%
## group by salaries & get count
# grpby_salaries_df = new_df2.groupby(["salary"]).agg[{"salary": "count"}]

#grpby_salaries_df = new_df2.groupby(["salary"])

grpby_title_id_df = new_df2.groupby(["title_id"])
grpby_title_id_df.head()
# Out:
#         emp_no emp_title_id  birth_date   first_name    last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki     Zallocco   M
# 1       421786        s0001  1957-09-28        Xiong     Verhoeff   M
# 2       273487        s0001  1957-04-14    Christoph      Parfitt   M
# 3       246449        s0001  1958-03-23        Subbu   Bultermann   F
# 4        48085        s0001  1964-01-19   Venkatesan         Gilg   M
# 107384  475053        e0002  1954-11-18        Byong    Delgrande   F
# 107385   57444        e0002  1958-01-30        Berry         Babb   F
# 107386  477657        e0002  1962-12-18       Lihong    Magliocco   M
# 107387   29920        e0002  1961-12-31      Shuichi        Tyugu   F
# 107388   21529        e0002  1959-05-19        Bojan     Zallocco   M
# 154687  282238        e0003  1952-10-28   Abdelkader      Baumann   F
# 154688  263976        e0003  1959-10-30         Eran     Cusworth   M
# 154689  208153        e0003  1961-10-25      Abdulah         Lunn   M
# 154690   13616        e0003  1961-08-30        Perry        Lorho   F
# 154691   71530        e0003  1959-02-09   Venkatesan     McAlpine   M
# 252434  461591        s0002  1964-11-17       Xudong     Samarati   M
# 252435  219881        s0002  1956-04-24    Kwangyoen        Speek   F
# 252436  205246        s0002  1958-11-25        Nevio       Demizu   F
# 252437  105597        s0002  1956-08-14  Christfried    Kabayashi   M
# 252438   85093        s0002  1959-01-30    Nectarios       Covnot   M
# 279017   17934        e0004  1963-07-12     Bilhanan     Wuwongse   M
# 279018  240129        e0004  1952-08-11        Roddy       Karnin   M
# 279019   35270        e0004  1953-01-02       Masali     Bakhtari   M
# 279020  402202        e0004  1959-10-14         Leni  Pusterhofer   M
# 279021  419277        e0004  1953-10-10       Freyja        Uhrig   M
# 294165  252000        e0001  1952-12-03     Zhonghui     Gyimothy   F
# 294166  109820        e0001  1952-11-11    Juichirou       Ghelli   F
# 294167  268613        e0001  1952-05-08     Tadahiko     Cherinka   F
# 294168  441330        e0001  1962-12-06      Richara       Ducloy   M
# 294169   14193        e0001  1964-02-23       Lucien      Kornyak   F
# 300000  111877        m0001  1962-10-18      Xiaobin     Spinelli   F
# 300001  111534        m0001  1952-06-27       Hilary       Kambil   F
# 300002  110765        m0001  1954-05-22       Rutger      Hofmeyr   F
# 300003  110420        m0001  1963-07-27        Oscar     Ghazalie   M
# 300004  110725        m0001  1961-03-14    Peternela      Onuegbe   F
#
#          hire_date  salary title_id               title
# 0       1990-04-28   40000    s0001               Staff
# 1       1987-11-26   40000    s0001               Staff
# 2       1991-06-28   56087    s0001               Staff
# 3       1988-03-25   87084    s0001               Staff
# 4       1993-06-28   63016    s0001               Staff
# 107384  1991-09-07   53422    e0002            Engineer
# 107385  1992-03-21   48973    e0002            Engineer
# 107386  1993-10-23   54816    e0002            Engineer
# 107387  1995-01-17   40000    e0002            Engineer
# 107388  1986-10-14   40000    e0002            Engineer
# 154687  1991-01-18   40000    e0003     Senior Engineer
# 154688  1986-11-14   40000    e0003     Senior Engineer
# 154689  1989-04-08   50183    e0003     Senior Engineer
# 154690  1991-08-03   40000    e0003     Senior Engineer
# 154691  1989-03-31   69148    e0003     Senior Engineer
# 252434  1985-11-13   40000    s0002        Senior Staff
# 252435  1993-02-14   40000    s0002        Senior Staff
# 252436  1986-05-18   80252    s0002        Senior Staff
# 252437  1987-05-11   43841    s0002        Senior Staff
# 252438  1990-04-24   97816    s0002        Senior Staff
# 279017  1993-10-06   48795    e0004    Technique Leader
# 279018  1985-05-29   43548    e0004    Technique Leader
# 279019  1991-02-05   40338    e0004    Technique Leader
# 279020  1995-01-29   41006    e0004    Technique Leader
# 279021  1986-12-20   46833    e0004    Technique Leader
# 294165  1989-03-02   40000    e0001  Assistant Engineer
# 294166  1986-12-13   40000    e0001  Assistant Engineer
# 294167  1990-02-17   53960    e0001  Assistant Engineer
# 294168  1996-12-15   54270    e0001  Assistant Engineer
# 294169  1994-11-01   62604    e0001  Assistant Engineer
# 300000  1991-08-17   53846    m0001             Manager
# 300001  1988-01-31   48077    m0001             Manager
# 300002  1989-01-07   40055    m0001             Manager
# 300003  1992-02-05   40000    m0001             Manager
# 300004  1985-01-01   61357    m0001             Manager

# %%
# Figure out min & max values
print("Min ", salaries_df["salary"].min())
print("Max ", salaries_df["salary"].max())
# Out:
# Min  40000
# Max  129492

# %%
#BINNING -- create the bins for SALARY RANGES
bins = [0, 39999, 59999, 79999, 99999, 1000000]

group_labels = ["< $40k", "$40k-60k",  "$60-80k", "$80k-100k", "> $100k"]
group_labels
# Out:
# ['< $40k', '$40k-60k', '$60-80k', '$80k-100k', '> $100k']

# %%
# Slice the data and place it into bins
pd.cut(salaries_df["salary"], bins, labels=group_labels).head()
# Out:
# 0     $60-80k
# 1     $60-80k
# 2    $40k-60k
# 3    $40k-60k
# 4     $60-80k
# Name: salary, dtype: category
# Categories (5, object): ['< $40k' < '$40k-60k' < '$60-80k' < '$80k-100k' < '> $100k']

# %%
# Creating histogram using PANDAS.
salaries_df.plot(kind="hist")
plt.legend()
plt.close

# %%
salaries_count_df

# %%
# create a bar chart of average salary by title using pyplot

group_labels = ["< $40k", "$40k-60k",  "$60-80k", "$80k-100k", "> $100k"]

#x_axis = np.arange(0, len(county_pop))
x_axis = np.arange(0, len(group_labels))

# Tell matplotlib that chart to be created is a bar chart
# Apply align="edge" to ensure the bars line up with the tick marks
plt.bar(x_axis, group_labels, facecolor="blue", alpha=0.75, align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]

# pass in the tick location and the label you want to appear on the ticks (in order)
#plt.xticks(tick_locations, drugs, rotation="vertical")
plt.xticks(tick_locations, group_labels, rotation=65)

# Sets the x limits of the current chart
# using len(x_axis)-0.25 will go to the last value in your x-axis and come back a small amount. 
# This is based on the size of your data

plt.xlim(-0.75, len(x_axis)-0.25)

plt.ylim(0, max(salaries_df['salary'])+500000, +1000)

# Set a Title and labels
plt.title("Salaries by Group")
plt.xlabel("Salary Groups")
plt.ylabel("Salaries)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/mb_avg_salary.png")

plt.show()

plt.close

# %%
# create a bar chart of average salary by title

#salaries_count_df.plot(kind="bar")

#salaries_df.plot(kind="bar" hist(column='salary')


salaries_df.plot(kind="bar")

plt.show
plt.legend()
plt.close

# %%
# --- opt 2
# bar chart using pandas

salaries_count_df.plot(kind="bar")

# Set a Title and labels
plt.title("Total Number of Calls by County")
plt.xlabel("Salaries")
plt.ylabel("Salaries -- Count")

plt.tight_layout()

#plt.tight_layout(pad=100000000.0)

plt.legend()

#save the chart figure
# plt.savefig("../Images/<xyz.png")

plt.close
